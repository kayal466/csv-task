# %% [markdown]
# <a href="https://colab.research.google.com/github/kayal466/csv-task/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
import pandas as pd
data1=pd.read_csv("/content/college_1.csv")
data2=pd.read_csv("/content/college_2.csv")
df=pd.DataFrame(data1)
df1=pd.DataFrame(data2)

# %%
data3=[df,df1]
final=pd.concat(data3)

# %%
final
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
exceed=df["CodeKata Score"]

# %%
l=[]
for i in exceed:
  if i>=15000:
    l.append(i)

print(l)
# Out:
# [24500, 21740, 19680]

# %%
df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
exceed1=df1["CodeKata Score"]
l1=[]
for i in exceed1:
  if i>=15000:
    l1.append(i)

print(l1)
# Out:
# [19400]

# %%
score={'codekata score':[24500, 21740, 19680,19400]}
Exceededexpectation=pd.DataFrame(score)
Exceededexpectation.to_csv("Exceededexpectation.csv")
#print(Exceededexpectation)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
exceed2=df1["CodeKata Score"]
l2=[]
for i in exceed2:
  if i>10000 and i<15000:
    l2.append(i)
print(l2)
# Out:
# [14490, 10790, 10040]

# %%
exceed3=df["CodeKata Score"]
l3=[]
for i in exceed3:
  if i>10000 and i<15000:
    l3.append(i)
print(l3)
# Out:
# [10610]

# %%
score={'codekata score':[14490, 10790,10610, 10040]}
Reachedexpectation=pd.DataFrame(score)
Reachedexpectation.to_csv("Reachedexpectation.csv")

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
exceed4=df1["CodeKata Score"]
l4=[]
for i in exceed4:
  if i<7000 and i<10000:
    l4.append(i)
print(l4)
# Out:
# [6800, 6640, 6290, 6090, 5740, 5200, 5050, 4820, 4440, 4170, 4020, 3220, 2380, 1890, 1720, 0, 0]

# %%
exceed5=df["CodeKata Score"]
l5=[]
for i in exceed5:
  if i<7000 and i<10000:
    l5.append(i)
print(l5)
# Out:
# [5860, 5500, 5400, 5380, 5280, 5120, 4800, 4600, 4510, 4370, 4320, 4090, 3915, 3665, 3460, 3280, 3200, 3200, 3110, 3000, 2570, 2410, 2360, 2260, 2240, 2160, 1910, 1910, 1900, 1880, 1880, 1740, 1680, 1580, 1580, 1440, 1350, 1320, 1240, 1130, 1100, 1020, 980, 950, 850, 800, 770, 760, 720, 690, 580, 490, 410, 380, 300, 270, 260, 200, 180, 170, 160, 120, 120, 120, 120, 100, 100, 60, 40, 40, 40, 0, 0, 0, 0, 0]

# %%
score={'codekata score':[14490, 10790,10610, 10040]}
Reachedexpectation=pd.DataFrame(score)
Reachedexpectation.to_csv("Reachedexpectation.csv")

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
exceed6=df1["CodeKata Score"]
l6=[]
for i in exceed6:
  if i<7000:
    l6.append(i)
print(l6)
# Out:
# [6800, 6640, 6290, 6090, 5740, 5200, 5050, 4820, 4440, 4170, 4020, 3220, 2380, 1890, 1720, 0, 0]

# %%
exceed7=df["CodeKata Score"]
l7=[]
for i in exceed7:
  if i<7000:
    l7.append(i)
print(l7)
# Out:
# [5860, 5500, 5400, 5380, 5280, 5120, 4800, 4600, 4510, 4370, 4320, 4090, 3915, 3665, 3460, 3280, 3200, 3200, 3110, 3000, 2570, 2410, 2360, 2260, 2240, 2160, 1910, 1910, 1900, 1880, 1880, 1740, 1680, 1580, 1580, 1440, 1350, 1320, 1240, 1130, 1100, 1020, 980, 950, 850, 800, 770, 760, 720, 690, 580, 490, 410, 380, 300, 270, 260, 200, 180, 170, 160, 120, 120, 120, 120, 100, 100, 60, 40, 40, 40, 0, 0, 0, 0, 0]

# %%
exceed6=df1["CodeKata Score"]
score={'codekata score':[5860, 5500, 5400, 5380, 5280, 5120, 4800, 4600, 4510, 4370, 4320, 4090, 3915, 3665, 3460, 3280, 3200, 3200, 3110, 3000, 2570, 2410, 2360, 2260, 2240, 2160, 1910, 1910, 1900, 1880, 1880, 1740, 1680, 1580, 1580, 1440, 1350, 1320, 1240, 1130, 1100, 1020, 980, 950, 850, 800, 770, 760, 720, 690, 580, 490, 410, 380, 300, 270, 260, 200, 180, 170, 160, 120, 120, 120, 120, 100, 100, 60, 40, 40, 40, 0, 0, 0, 0, 0,]}
Unsatisfactory=pd.DataFrame(score)
Unsatisfactory.to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['avg']=df["Previous Geekions"]+df["CodeKata Score"].mean()
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising           avg  avg1  \
# ...

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising  avg
# 0         Computer Science and Engineering       0  1.0
# ...

# %%
df1['avg1']=df1["Previous Geekions"]+df1["CodeKata Score"].mean()
df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %% [markdown]
# ###### No of students participated

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df1['average']=df1['mysql'] + df1['computational_thinking'] + df1['python_en'] + df1['python'].mean()
df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df['average1']=df['mysql'] + df['python'].mean()
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising  avg  avg1    average1
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df4=df[['Name','Rising']].max()
df4
# Out:
# Name      yaser ahamed.A
# Rising               130
# dtype: object

# %%
df.sort_values('Rising')
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 60    muvendiran.m   100.0    7.5                410             410
# 59        Thivviya    82.0    8.0                490             490
# 58    M.Nisha@mary    11.0   20.0                580             580
# 57         M.PRIYA    43.0   24.0                690             690
# ..             ...     ...    ...                ...             ...
# 24         MEERA.M   100.0  100.0               3200            3200
# 23          balaji    82.0    0.0               3280            3280
# 31  Kaliaperumal G   100.0    0.0               2260            2260
# 83  yaser ahamed.A     0.0   27.0                  0               0
# 6    KALAIARASAN K    85.0   47.0               7750            7880
#
#                                    Department  Rising           avg  avg1  \
# ...

# %%
df.sort_values(by=['Rising'], inplace=True, ascending=False)
df.head(3)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 6   KALAIARASAN K    85.0   47.0               7750            7880
# 0       A.Dharani    82.0   20.0              24500           24500
# 53      RANJITH.R   100.0    0.0                800             800
#
#                                    Department  Rising           avg  avg1  \
# 6   Electronics and Communication Engineering     130  10656.071429   NaN
# 0            Computer Science and Engineering       0  27406.071429   NaN
# 53  Electronics and Communication Engineering       0   3706.071429   NaN
#
#       average1
# 6   120.392857
# 0    93.392857
# 53   73.392857

# %%
df1.sort_values(by=['Rising'], inplace=True, ascending=False)
df1.head(3)
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N      58          0      0                       0
# 18     Narasimhan Y L      -1         -1      0                       0
# 2   Ganesh Ramkumar R      -1         55     24                       6
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 18               4800            6800        Computer Science and Engineering
# 2                8790           10790        Computer Science and Engineering
#
#     Rising          avg1    average
# 8     3140  11981.428571   8.657143
# 18    2000  11601.428571   7.657143
# 2     2000  15591.428571  93.657143

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by=['Previous Geekions'], inplace=True, ascending=False)
df.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising           avg  avg1    average1
# 0  Computer Science and Engineering       0  27406.071429   NaN   93.392857
# 1  Computer Science and Engineering       0  24646.071429   NaN   93.392857
# 2  Computer Science and Engineering       0  22586.071429   NaN  173.392857

# %%
df1.sort_values(by=['Previous Geekions'], inplace=True, ascending=False)
df1.head(3)
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0    ASHOK KUMAR K     100          0     31                       9
# 1          Chandru       0         20      0                       0
# 3  Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 3              10040           10040
#
#                                   Department  Rising          avg1    average
# 0     Electronics and Electrical Engineering       0  26201.428571  48.657143
# 1           Computer Science and Engineering     340  20951.428571  28.657143
# 3  Electronics and Communication Engineering       0  16841.428571  42.657143

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%')

# %%
df1.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
import matplotlib.pyplot as plt

# %%
df1.groupby(['Department','Name']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%')

# %%
df1.groupby(['Department','Name']).sum().plot(kind='pie', y='Previous Geekions',autopct='%1.0f%%')

# %%
fig=px.bar(df1,x='Department',y='CodeKata Score',hover_name="Name",animation_frame="Previous Geekions",range_y=[0,25000])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot.barh(x='Department', y='Previous Geekions',
             title='Toppers', color='pink')
